# %% [markdown]
# ### DFS - Binary Tree
#
#
#
# ***Q )*** 이진트리를 깊이 우선 탐색으로 전위 순회, 후위 순회 하는 코드 작성
#
# ***A)***
#
# - 전위 순회 : 부모 노드 => 왼쪽 노드 => 오른쪽 노드
#
# - 중위 순회 : 왼쪽 노드 => 부모 노드 => 오른쪽 노드
#
# - 후위 순회 : 왼쪽 노드 => 오른쪽 노드 => 부모 노드

# %%
inputs = input()
# Out:
# 1 2 3 4 5 6 7

# %%
input_list = [ int(v) for v in inputs.split()]

# %% [markdown]
# ## 전위 순회

# %%
def dfs(x):
  if x회in input_list:
    print(x)
    dfs(2*x)
    dfs(2*x+1)

# %%
dfs(1)
# Out:
# 1
# 2
# 4
# 5
# 3
# 6
# 7

# %% [markdown]
# ## 후위 순회

# %%
def dfs(x):
  if x in input_list:
    dfs(2*x)
    dfs(2*x+1)
    print(x회

# %%
dfs(1)
# Out:
# 4
# 5
# 2
# 6
# 7
# 3
# 1
