# %% [markdown]
# ### Greedy - 2
#
# ***Q )*** 운동선수가 5명이고, 각 선수들의 키와 몸무게가 주어진다. 이때, 자신보다 몸무게와 키 값 둘 모두 큰 선수가 있다면 해당 선수는 선발에서 탈락한다. 선발되는 선수는 몇명인가?
#
# ***A )***
# 1. 선수들의 키를 기준으로 내림차순 소팅한다.
#
# 2. 키가 가장 큰 선수는 무조건 선발되므로 count = 1 이다.
#
# 3. 다음 선수의 선발 여부를 결정할때에는, 자기보다 키가 큰 선수들과의 몸무게 값만 비교하면된다.
#
# ( 자기보다 키가 작은 선수들과의 비교에서는 자신이 키가 가장 크기 때문에 선발에서 탈락하지 않기 때문이다. )
#
# 4. 몸무게 값이 크다면, 선발에 해당된다.
#
# 위의 과정을 반복한다.

# %%
inputs = input()
# Out:
# 5 193 68 175 56 177 68 175 68 169 77

# %%
input_list = [ int(val) for val in inputs.split()]

# %%
all_n = input_list[0]
input_list = input_list[1:]

# %%
players = [ ( input_list[i*2], input_list[i*2+1] ) for i in range(len(input_list)//2)]

# %%
players.sort(reverse = True)

# %%
max_w = players[0][1]

# %%
count = 1

# %%
for h, w in players :
  if w > max_w :
    max_w = w
    count += 1

# %%
count
# Out:
# 2

# %%
w_tmp = 0
h_tmp = 0
count = 0

# %%
max_h = max(players)

# %%
max_h
# Out:
# (183, 65)

# %%
max_w = max()

# %%
for w, h in players:
# Out:
#   File "<ipython-input-97-0be41473330e>", line 1
#     for w, h in players:
#                         ^
# SyntaxError: unexpected EOF while parsing

# %%
if

# %%
times_list.sort(key=lambda x : (x[1], x[0]))

# %%
end_t = 0
count = 0
for start, end in times_list :
  if end_t <= start :
    count += 1
    end_t = end

# %%
count
# Out:
# 2
